# %%
import pandas as pd

# %%
similarity_pairs_df = pd.read_csv('../top_3_roles.csv')

# %%
similarity_pairs_df
# Out:
#                           role                top_role_1  \
# 0    Digital Marketing Manager         Marketing Manager
# 1                  Bank Teller              Loan Officer
# 2                   Bus Driver              Truck Driver
# 3                    Assembler    Maintenance Technician
# 4                 Cardiologist         Community Manager
# ..                         ...                       ...
# 206                   Packager  Administrative Assistant
# 207                  Biologist           Project Manager
# 208                   Educator         Community Manager
# 209                   Mediator           Project Manager
# 210                  Geologist           Project Manager
#
#                           top_role_2              top_role_3
# 0        Customer Experience Manager   Marketing Coordinator
# 1    Customer Service Representative       Community Manager
# 2                  Warehouse Manager       Community Manager
# 3                  Warehouse Manager      Equipment Operator
# 4                  Software Engineer    Full-Stack Developer
# ..                               ...                     ...
# 206                  Sales Associate                 Cashier
# 207                Community Manager  Environmental Engineer
# 208                 School Principal          Branch Manager
# 209                Community Manager            Loan Officer
# 210           Environmental Engineer        Project Engineer
#
# [211 rows x 4 columns]

# %%
similarity_pairs_df=similarity_pairs_df.melt(['role'], var_name='index', value_name='similar')
similarity_pairs_df['index']=similarity_pairs_df['index'].str[-1].astype(int)

# %%
similarity_pairs_df
# Out:
#                           role  index                 similar
# 0    Digital Marketing Manager      1       Marketing Manager
# 1                  Bank Teller      1            Loan Officer
# 2                   Bus Driver      1            Truck Driver
# 3                    Assembler      1  Maintenance Technician
# 4                 Cardiologist      1       Community Manager
# ..                         ...    ...                     ...
# 628                   Packager      3                 Cashier
# 629                  Biologist      3  Environmental Engineer
# 630                   Educator      3          Branch Manager
# 631                   Mediator      3            Loan Officer
# 632                  Geologist      3        Project Engineer
#
# [633 rows x 3 columns]
